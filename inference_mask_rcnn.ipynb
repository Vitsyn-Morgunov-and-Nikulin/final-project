# %%
import sys
import os
import pandas as pd
from pathlib import Path
import cv2

import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import torch
from torchvision.models.detection import maskrcnn_resnet50_fpn
import albumentations as A
from albumentations.pytorch import ToTensorV2
from skimage.color import gray2rgb
from torchvision.ops import nms
from pytorch_toolbelt.utils import to_numpy
from dotenv import load_dotenv
from torchvision.utils import draw_segmentation_masks

from src.visualization import tensor_to_image
from src.utils import annotation2mask


current_dir = Path(".")
load_dotenv()
current_dir.absolute()
# Out:
# PosixPath('/home/danis/Projects/Miscellaneous/PMLDL/Lab/final-project')

# %%
# Global config of configuration
test_images_dir = Path(os.environ['dataset_path']) / "hidden_test"
weights_dir = current_dir / "weights" / "solution_for_027-2021-12-25.20-11-49.ckpt"
device = "cpu"

# %%
# Local tunable parameters of evaluation
score_threshold = 0.0  # All predictions would be counted, even with low score
nms_threshold = 0.2  # Overlapping instances will be dropped, lower - lower overlap is permitted
mask_threshold = 0.5  # Cut masks by the threshold

# %%
assert test_images_dir.is_dir(), f"Check test dir path for correctness, was looking at {test_images_dir.absolute()}"
assert weights_dir.is_file(), f"File not found, was looking at {weights_dir.absolute()}"

# %%
preprocess_image = A.Compose([
    A.Normalize(mean=(0.485,), std=(0.229,)),
    ToTensorV2(),
])

# %%
model = maskrcnn_resnet50_fpn(progress=False, num_classes=4)
model.load_state_dict(torch.load(weights_dir, map_location=torch.device("cpu")))
model.to(device)
model = model.eval()

# %%
image_paths = list(test_images_dir.glob("**/*.png"))

# %%
def load_image(image_path: str):
    image = io.imread(str(image_path))
    return image

# %%
def get_masks_from_image(image):
    image = preprocess_image(image=image)['image']
    image = image.to(device)
    
    with torch.no_grad():
        output = model.forward([image])[0]

    scores = output['scores'].detach().cpu()
    masks = output['masks'].squeeze().detach().cpu()
    boxes = output['boxes'].detach().cpu()

    print(f"found {len(boxes)} instances!")

    masks = (masks >= mask_threshold).int()

    # Now some masks can be empty (all zeros), we need to exclude them
    indices = torch.as_tensor([torch.sum(mask) > 0 for mask in masks])
    masks, boxes, scores = masks[indices], boxes[indices], scores[indices]

    print(f"After mask thresholding survived {len(masks)} instances")

    indices = scores >= score_threshold
    masks, boxes, scores = masks[indices], boxes[indices], scores

    print(f"After confidence thresholding survived {len(masks)} instances")

    indices = nms(boxes, scores, nms_threshold)
    masks, boxes, scores = masks[indices], boxes[indices], scores[indices]

    print(f"Finally, after NMS survived {len(masks)} instances!") 
    return masks

# %%
def to_rgb_image(im: torch.Tensor):
    return np.transpose(im.numpy(), axes=(1, 2, 0))


def draw_segmentation_mask(image, masks):
    gt_image = gray2rgb(image.squeeze())
    gt_image = torch.as_tensor(np.transpose(gt_image, axes=(2, 0, 1)), dtype=torch.uint8)
    gt_masks = torch.as_tensor(masks == 1)

    segm = draw_segmentation_masks(
        image=gt_image,
        masks=gt_masks,
        alpha=0.5
    )
    return to_rgb_image(segm)

# %% [markdown]
# # Run inference on validation images

# %%
def load_true_masks(image_path: Path):
    data_csv = pd.read_csv(test_images_dir / "test.csv")
    data_csv = data_csv.groupby(['id', 'cell_type'])['annotation'].agg(lambda x: list(x)).reset_index()
    annotations = data_csv[data_csv.id == image_path.stem].annotation.item()
    masks = np.array(list(map(lambda line: annotation2mask(line), annotations)))
    return torch.tensor(masks)

# %%
save_path = Path("figures") / "mask_r_cnn_mask_prediction"
save_path.mkdir(parents=True, exist_ok=True)

for image_path in image_paths:
    image = load_image(image_path)
    predicted_masks = get_masks_from_image(image)
    image_with_mask = draw_segmentation_mask(image, predicted_masks)
    cv2.imwrite(str(save_path/image_path.name), image_with_mask)
# Out:
# found 29 instances!
# After mask thresholding survived 29 instances
# After confidence thresholding survived 29 instances
# Finally, after NMS survived 26 instances!
# found 45 instances!
# After mask thresholding survived 45 instances
# After confidence thresholding survived 45 instances
# Finally, after NMS survived 39 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 59 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 98 instances!
# found 26 instances!
# After mask thresholding survived 26 instances
# After confidence thresholding survived 26 instances
# Finally, after NMS survived 25 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 100 instances!
# found 46 instances!
# After mask thresholding survived 46 instances
# After confidence thresholding survived 46 instances
# Finally, after NMS survived 42 instances!
# found 38 instances!
# After mask thresholding survived 38 instances
# After confidence thresholding survived 38 instances
# Finally, after NMS survived 31 instances!
# found 32 instances!
# After mask thresholding survived 32 instances
# After confidence thresholding survived 32 instances
# Finally, after NMS survived 31 instances!
# found 35 instances!
# After mask thresholding survived 35 instances
# After confidence thresholding survived 35 instances
# Finally, after NMS survived 35 instances!
# found 38 instances!
# After mask thresholding survived 38 instances
# After confidence thresholding survived 38 instances
# Finally, after NMS survived 34 instances!
# found 87 instances!
# After mask thresholding survived 87 instances
# After confidence thresholding survived 87 instances
# Finally, after NMS survived 40 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 99 instances!
# found 86 instances!
# After mask thresholding survived 86 instances
# After confidence thresholding survived 86 instances
# Finally, after NMS survived 65 instances!
# found 30 instances!
# After mask thresholding survived 30 instances
# After confidence thresholding survived 30 instances
# Finally, after NMS survived 30 instances!
# found 46 instances!
# After mask thresholding survived 46 instances
# After confidence thresholding survived 46 instances
# Finally, after NMS survived 45 instances!
# found 86 instances!
# After mask thresholding survived 86 instances
# After confidence thresholding survived 86 instances
# Finally, after NMS survived 50 instances!
# found 74 instances!
# After mask thresholding survived 74 instances
# After confidence thresholding survived 74 instances
# Finally, after NMS survived 37 instances!
# found 67 instances!
# After mask thresholding survived 67 instances
# After confidence thresholding survived 67 instances
# Finally, after NMS survived 58 instances!
# found 30 instances!
# After mask thresholding survived 30 instances
# After confidence thresholding survived 30 instances
# Finally, after NMS survived 28 instances!
# found 50 instances!
# After mask thresholding survived 50 instances
# After confidence thresholding survived 50 instances
# Finally, after NMS survived 28 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 79 instances!
# found 23 instances!
# After mask thresholding survived 23 instances
# After confidence thresholding survived 23 instances
# Finally, after NMS survived 20 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 100 instances!
# found 90 instances!
# After mask thresholding survived 90 instances
# After confidence thresholding survived 90 instances
# Finally, after NMS survived 58 instances!
# found 36 instances!
# After mask thresholding survived 36 instances
# After confidence thresholding survived 36 instances
# Finally, after NMS survived 33 instances!
# found 39 instances!
# After mask thresholding survived 39 instances
# After confidence thresholding survived 39 instances
# Finally, after NMS survived 25 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 100 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 89 instances!
# found 38 instances!
# After mask thresholding survived 38 instances
# After confidence thresholding survived 38 instances
# Finally, after NMS survived 37 instances!
# found 21 instances!
# After mask thresholding survived 21 instances
# After confidence thresholding survived 21 instances
# Finally, after NMS survived 21 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 67 instances!
# found 49 instances!
# After mask thresholding survived 49 instances
# After confidence thresholding survived 49 instances
# Finally, after NMS survived 45 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 80 instances!
# found 45 instances!
# After mask thresholding survived 45 instances
# After confidence thresholding survived 45 instances
# Finally, after NMS survived 31 instances!
# found 29 instances!
# After mask thresholding survived 29 instances
# After confidence thresholding survived 29 instances
# Finally, after NMS survived 24 instances!
# found 26 instances!
# After mask thresholding survived 26 instances
# After confidence thresholding survived 26 instances
# Finally, after NMS survived 23 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 100 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 100 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 100 instances!
# found 85 instances!
# After mask thresholding survived 85 instances
# After confidence thresholding survived 85 instances
# Finally, after NMS survived 80 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 100 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 77 instances!
# found 100 instances!
# After mask thresholding survived 100 instances
# After confidence thresholding survived 100 instances
# Finally, after NMS survived 57 instances!
# found 49 instances!
# After mask thresholding survived 49 instances
# After confidence thresholding survived 49 instances
# Finally, after NMS survived 43 instances!
# found 96 instances!
# After mask thresholding survived 96 instances
# After confidence thresholding survived 96 instances
# Finally, after NMS survived 65 instances!
# found 54 instances!
# After mask thresholding survived 54 instances
# After confidence thresholding survived 54 instances
# Finally, after NMS survived 51 instances!
# found 30 instances!
# After mask thresholding survived 29 instances
# After confidence thresholding survived 29 instances
# Finally, after NMS survived 28 instances!
# found 48 instances!
# After mask thresholding survived 48 instances
# After confidence thresholding survived 48 instances
# Finally, after NMS survived 48 instances!
# found 48 instances!
# After mask thresholding survived 48 instances
# After confidence thresholding survived 48 instances
# Finally, after NMS survived 45 instances!

# %% [markdown]
# # Visualize model predictions, online

# %%
def visualize_results(pred_segm, true_segm):    
    fig, axes = plt.subplots(ncols=2, figsize=(16, 8))
    axes[0].imshow(pred_segm)
    axes[0].set_title("Predicted masks")
    axes[1].imshow(true_segm)
    axes[1].set_title("True masks")
    for ax in axes:
        ax.set_xticks([])
        ax.set_yticks([])
    plt.tight_layout(pad=0.1, h_pad=0.1, w_pad=0.1)
    plt.show()

# %%
image_path = image_paths[0]

image = load_image(image_path)
predicted_masks = get_masks_from_image(image)
true_masks = load_true_masks(image_path)
predicted_image = draw_segmentation_mask(image, predicted_masks)
true_image = draw_segmentation_mask(image, true_masks)
visualize_results(predicted_image, true_image)
# Out:
# found 29 instances!
# After mask thresholding survived 29 instances
# After confidence thresholding survived 29 instances
# Finally, after NMS survived 26 instances!
